# %%
# pip install webdriver_manager
# pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://www.youtube.com/c/TriggeredInsaan/videos'
driver.get(url)

element = driver.find_element(By.TAG_NAME , 'body')

element.send_keys(Keys.PAGE_DOWN)

t=0

while t <= 10 :
    element.send_keys(Keys.PAGE_DOWN)
    
    time.sleep(2)
    
    t += 1
    
    
vid = driver.find_elements(By.CLASS_NAME , 'style-scope ytd-rich-grid-media')

list_ = []

for video in vid:
    title = video.find_element(By.XPATH , './/*[@id="video-title"]').text
    views = video.find_element(By.XPATH , './/*[@id="metadata-line"]/span[1]').text
    when = video.find_element(By.XPATH , './/*[@id="metadata-line"]/span[2]').text
    #print(title,views,when)
    vid_item = {
        'title' : title ,
        'views' : views ,
        'posted_time' : when
    }
    
    list_.append(vid_item)
    
df = pd.DataFrame(list_)

df
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_236/1835857485.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#                                                 title       views  \
# 0   Indian TV Serials are Just Unbelievable Now😂 |...  3.5M views
# 1   I Gave Students ₹100,000 on Omegle (Part 2) | ...  5.3M views
# 2                  Neha Kakkar's New Song is so Funny  7.1M views
# 3               I'm in Golmaal 5 😂 - Triggered Insaan  4.9M views
# 4          Bollywood Movies Destroyed Logic & Gravity  7.6M views
# 5   I Proposed Dhinchak Pooja after Listening Her ...   10M views
# 6   I Gave Students ₹100,000 on Omegle | Triggered...  9.5M views
# 7      My Best Friend Called Police on Me (Storytime)  4.1M views
# 8     The Greatest Legends of Social Media (ft. Papa)  5.6M views
# 9                Tiger Shroff Roast | Bollywood Roast  8.2M views
# ...

# %%
df.to_csv('GAURAV1')

# %%
df.head(10)
# Out:
#                                                title       views   posted_time
# 0  Indian TV Serials are Just Unbelievable Now😂 |...  3.5M views    3 days ago
# 1  I Gave Students ₹100,000 on Omegle (Part 2) | ...  5.3M views   2 weeks ago
# 2                 Neha Kakkar's New Song is so Funny  7.1M views   3 weeks ago
# 3              I'm in Golmaal 5 😂 - Triggered Insaan  4.9M views   1 month ago
# 4         Bollywood Movies Destroyed Logic & Gravity  7.6M views   1 month ago
# 5  I Proposed Dhinchak Pooja after Listening Her ...   10M views   1 month ago
# 6  I Gave Students ₹100,000 on Omegle | Triggered...  9.5M views  2 months ago
# 7     My Best Friend Called Police on Me (Storytime)  4.1M views  2 months ago
# 8    The Greatest Legends of Social Media (ft. Papa)  5.6M views  2 months ago
# 9               Tiger Shroff Roast | Bollywood Roast  8.2M views  2 months ago

# %%
df.tail(10)
# Out:
#                                                 title       views posted_time
# 50    Can You Solve These Big Brain Riddles **Weird**   17M views  1 year ago
# 51                        Funniest Hairstyles Ever #3   11M views  1 year ago
# 52      My First Date was Ruined by a Dog (Storytime)  8.7M views  1 year ago
# 53                      Thara Bhai Joginder - The END   25M views  1 year ago
# 54  Funniest Things People GOOGLE About Me😂 (Roast...   10M views  1 year ago
# 55  Thara Bhai Joginder is the Funniest Instagram ...   16M views  1 year ago
# 56                  100 BILLION DIRHAM SETUP TOUR RIP   10M views  1 year ago
# 57              Funniest Bangladeshi Action Scenes #2   12M views  1 year ago
# 58   I Found The Funniest Songs - Tony Kakkar Special   14M views  1 year ago
# 59                   Sahi Khel Gaya Ladka (Storytime)   11M views  1 year ago
