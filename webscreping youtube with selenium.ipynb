# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
#first,we have to download chrome web driver 
driver = webdriver.Chrome(Chrome webdriver path written here)
url = 'https://www.youtube.com/c/TriggeredInsaan/videos'
driver.get(url)

time.sleep(3)

element = driver.find_element(By.TAG_NAME , 'body')

element.send_keys(Keys.PAGE_DOWN)

t=0

while t <= 6 :
    element.send_keys(Keys.PAGE_DOWN)
    
    time.sleep(3)
    
    t += 1
    
    
vid = driver.find_elements(By.CLASS_NAME , 'style-scope ytd-grid-video-renderer')

list_ = []

for video in vid:
    title = video.find_element(By.XPATH , './/*[@id="video-title"]').text
    views = video.find_element(By.XPATH , './/*[@id="metadata-line"]/span[1]').text
    when = video.find_element(By.XPATH , './/*[@id="metadata-line"]/span[2]').text
    #print(title,views,when)
    vid_item = {
        'title' : title ,
        'views' : views ,
        'posted_time' : when
    }
    
    list_.append(vid_item)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

df = pd.DataFrame(list_)

df
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_5876/4120219447.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\DELL\\Downloads\\chromedriver.exe')
#                                                 title       views  posted_time
# 0         I Gave Students ₹100,000 on Omegle (Part 2)  3.2M views   2 days ago
# 1                  Neha Kakkar's New Song is so Funny  5.9M views   9 days ago
# 2               I'm in Golmaal 5 😂 - Triggered Insaan  4.6M views  2 weeks ago
# 3          Bollywood Movies Destroyed Logic & Gravity  7.3M views  1 month ago
# 4   I Proposed Dhinchak Pooja after Listening Her ...   10M views  1 month ago
# ..                                                ...         ...          ...
# 85                  These Singers Cured My Depression   10M views   1 year ago
# 86            My First Crush: School Love (Storytime)   11M views   1 year ago
# ...

# %%
df.to_csv(file name given here)
